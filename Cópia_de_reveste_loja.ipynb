# %% [markdown]
# <a href="https://colab.research.google.com/github/viitorgustavo2003-ux/REVESTE/blob/main/C%C3%B3pia_de_reveste_loja.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("reveste")
print("sistema de vendas")

print ("1 registrar vendas")
print ("2 sair ")

opçao = (input("escolha uma opçao"))
if opçao == "1":
  print("registrar vendas")

  produto = input ("qual o produto ")
  preço = float(input("polo reveste :"))
  quantidade = int(input("quantidade:"))

  total = preço * quantidade
  print("valor total:",total)

elif opçao == "2":
      print("saindo do sistema:")

else:
 print("opçao invalida")
# Out:
# reveste
# sistema de vendas
# 1 registrar vendas
# 2 sair
# escolha uma opçao1
# registrar vendas
# qual o produto polo
# polo reveste :55
# quantidade:1
# valor total: 55.0

# %%
print("contabilidade da loja reveste")

valor_entrada_por_dia = float(input("quanto entra por dia "))
dias = 31
total_mes = dias*valor_entrada_por_dia
print("valor total de lucro no mes",total_mes)

meses= 12

valor_total_de_lucro_no_ano = total_mes*meses
print("total de lucro no ano e de",valor_total_de_lucro_no_ano)

#despeja da loja

compra_de_mercadoria = float(input("qual valor da mercadoria"))
embalagem_e_sacola =   float(input("valor da embalagem e sacola?"))
total_despesa = compra_de_mercadoria + embalagem_e_sacola
print("total de despesa da loja",total_despesa*meses)
# Out:
# contabilidade da loja reveste
# quanto entra por dia 2000
# valor total de lucro no mes 62000.0
# total de lucro no ano e de 744000.0
# qual valor da mercadoria3000
# valor da embalagem e sacola?3000
# total de despesa da loja 72000.0
